# %% [markdown]
# VERY MESSY Document -- mostly just experiments -- final requester is function
#     get_abstract_from_doi

# %%
import requests
import cloudscraper
from bs4 import BeautifulSoup

# %%
doi_data = requests.get("https://besjournals.onlinelibrary.wiley.com/doi/full/10.1111/j.1365-2664.2004.00877.x")
                        #"https://www.doi.org/10.1111/j.1365-2664.2004.00877.x")

# %%
scraper = cloudscraper.create_scraper()
doi_data = scraper.get("https://www.doi.org/10.1111/j.1365-2664.2004.00877.x")

# %%
bs = BeautifulSoup(doi_data.text)

# %%
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html class="pb-page" data-request-id="117c40d3-df94-4d84-99b2-0842204734ba" lang="en">
#  <head data-pb-dropzone="head">
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content=";journal:journal:13652664;issue:issue:doi\:10.1111/jpe.2004.41.issue-1;page:string:Article/Chapter View;ctype:string:Journal Content;requestedJournal:journal:13652664;website:website:besjournals;wgroup:string:Publication Websites;pageGroup:string:Publication Pages;article:article:doi\:10.1111/j.1365-2664.2004.00877.x;subPage:string:Full Text" name="pbContext"/>
#   <script src="/pb-assets/optimizer-1611832262563.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var $DoubleClickZone = "j-app-eco_jpe";var $DoubleClickSite =  "wly.ecology_000046";
#   </script>
#   <script id="analyticDigitalData">
# ...

# %%
ith = bs.body.find_all(re.compile(r"h[1-5]"), string=re.compile(r"Summary|Abstract"))#class_=re.compile(".*abstract.*"))

# %%
ith[0].next_sibling.name #Search for the first div/p afterwards

# %%
scraper = cloudscraper.create_scraper()
doi_cam_data = scraper.get("https://www.doi.org/10.1017/S0030605312000658")
bscam = BeautifulSoup(doi_cam_data.text)

# %%
print(bscam.body.prettify()) #li/a/i link style
# Out:
# <body>
#  <noscript>
#   <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NTX72TG" style="display:none;visibility:hidden" width="0">
#   </iframe>
#  </noscript>
#  <a class="skiptocontent" href="#maincontent">
#   Skip to main content
#  </a>
#  <a class="skiptocontent" href="/core/accessibility">
#   Accessibility help
#  </a>
#  <div class="cookie-message">
#   <div class="row">
#    <div class="small-11 columns">
#     <p>
#      We use cookies to distinguish you from other users and to provide you with a better experience on our websites. Close this message to accept cookies or find out how to
#      <a href="https://www.cambridge.org/about-us/legal-notices/cookies-policy/" target="_blank">
#       manage your cookie settings
#      </a>
#      .
#     </p>
#    </div>
#    <div class="small-1 columns">
#     <a class="cookie-close" href="#" onclick="closeMessage();">
#      <!--[if IE 8 ]>
# ...

# %%
import re
it = bscam.body.find_all("div",class_=re.compile(".*abstract.*"))
ith = bscam.body.find_all(re.compile(r"h[1-5]"), string=re.compile(r"Summary|Abstract"))#class_=re.compile(".*abstract.*"))

# %%
for p in ith:
    print((p.next_sibling.next_sibling.get_text()))
# Out:
# There is growing awareness that small-scale fisheries may have large impacts on threatened marine fauna. Bycatch of small cetaceans by the Peruvian small-scale driftnet fleet results in the deaths of thousands of animals annually. We sought to assess the effectiveness of acoustic alarms (pingers) for reducing the incidental capture of dolphins and porpoises by this fleet. Forty-three experimental trips (156 fishing sets) and 47 control trips (195 fishing sets) out of Salaverry Port, northern Peru, were observed from April 2009 to August 2011. Twenty-two percent of control sets captured small cetaceans (67 individuals) and 16% of experimental sets had captures of small cetaceans (33 individuals). The bycatch rate of experimental sets was 0.50 individuals km−2h−1, whereas for control sets the rate was 0.80 individuals km−2h−1. This 37% reduction in bycatch rate suggests that pingers may be effective in reducing the bycatch of small cetaceans in this fishery. Catch rates of the fishery'
# ...

# %%
list(ith)[0].next_sibling.next_sibling
# Out:
# <div class="abstract-content"><div class="abstract" data-abstract-type="normal">
# ...

# %%
scraper = cloudscraper.create_scraper()
doi_ox_data = scraper.get("https://academic.oup.com/icesjms/article/59/4/816/676809")
bsox = BeautifulSoup(doi_ox_data.text)

# %%
ith = bsox.body.find_all(re.compile(r"h[1-5]"), string=re.compile(r"Summary|Abstract"))

# %%
ith[0].next_sibling.next_sibling
# Out:
# <section class="abstract"><p class="chapter-para">A field experiment with Dukane NetMark™ 1000 pingers was conducted in the bottom-set gillnet fishery for cod in the Swedish Skagerrak Sea between March and April 1997. The aim of the experiment was to evaluate (i) the effectiveness of pingers to reduce by-catch rate of harbour porpoises, and (ii) the effects of pingers on the catches of the target species in the fishery. The design of the study was based on a statistical power analysis and the results from observer programmes conducted 1995–1996 in the same area, fishery and time of year.</p><p class="chapter-para"> The catches of cod, pollack and other fish species were not affected by the sound of the pingers in the active strings. No harbour porpoise was caught in any control or active string, which was a significantly lower by-catch rate than in the two previous years. This could not be explained by a reduction in fishing effort <em>per se</em> , a difference in the total catch of
# ...

# %% [markdown]
# IDEA: Search for header containing Abstract/Summary... Then search for first sibling that is p/div/section (maybe check for class?
#
# Search for dic section p with class abstract -- Maybe check for text length inside
#
# Continuously decrease search complexity

# %%
it2 = bsox.find_all(re.compile("section|p|div"), class_=re.compile(".*abstract.*"))

# %%
it2[0].parent.parent.parent.get_text()
# Out:
# "\n\n\nAbstract\nA field experiment with Dukane NetMark™ 1000 pingers was conducted in the bottom-set gillnet fishery for cod in the Swedish Skagerrak Sea between March and April 1997. The aim of the experiment was to evaluate (i) the effectiveness of pingers to reduce by-catch rate of harbour porpoises, and (ii) the effects of pingers on the catches of the target species in the fishery. The design of the study was based on a statistical power analysis and the results from observer programmes conducted 1995–1996 in the same area, fishery and time of year. The catches of cod, pollack and other fish species were not affected by the sound of the pingers in the active strings. No harbour porpoise was caught in any control or active string, which was a significantly lower by-catch rate than in the two previous years. This could not be explained by a reduction in fishing effort per se , a difference in the total catch of fish for consumption or a shift in the spatial distribution of the se
# ...

# %%
bscam.find_all(re.compile("section|p|div"), class_="abstract")[0].parent.parent.parent.get_text() #".*abstract.*"
# Out:
# "Abstract \nThere is growing awareness that small-scale fisheries may have large impacts on threatened marine fauna. Bycatch of small cetaceans by the Peruvian small-scale driftnet fleet results in the deaths of thousands of animals annually. We sought to assess the effectiveness of acoustic alarms (pingers) for reducing the incidental capture of dolphins and porpoises by this fleet. Forty-three experimental trips (156 fishing sets) and 47 control trips (195 fishing sets) out of Salaverry Port, northern Peru, were observed from April 2009 to August 2011. Twenty-two percent of control sets captured small cetaceans (67 individuals) and 16% of experimental sets had captures of small cetaceans (33 individuals). The bycatch rate of experimental sets was 0.50 individuals km−2h−1, whereas for control sets the rate was 0.80 individuals km−2h−1. This 37% reduction in bycatch rate suggests that pingers may be effective in reducing the bycatch of small cetaceans in this fishery. Catch rates of 
# ...

# %%
bs.find_all(re.compile("section|p|div"), class_="abstract")
# Out:
# []

# %%
import re
import requests
import cloudscraper
from bs4 import BeautifulSoup
import unidecode
from urllib.parse import unquote
from pathlib import Path
import json
import pandas as pd

urlreg = re.compile(r"http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+")

def get_abstract_from_doi(doi : str):
    scraper = cloudscraper.create_scraper()
    doi_data = scraper.get(f"https://www.doi.org/{doi}", timeout=10)
    doi_bs = BeautifulSoup(doi_data.text)
   
    if doi_data.url.startswith('https://link.springer.com/') and \
        not doi_data.url.startswith('https://link.springer.com/article'):
        cleaned_link = doi_data.url.replace('https://link.springer.com/', 
                                            'https://link.springer.com/article/')
        doi_data = scraper.get(cleaned_link, timeout=10)
        doi_bs = BeautifulSoup(doi_data.text)

    #Check whether we landed at a javascript redirect page
    attempts = 0
    while len(doi_bs.get_text()) < 150:
        if attempts > 3:
            return None
        attempts = attempts + 1
        pattern = re.compile(r"\?Redirect=(.*);") 
        match = pattern.search(doi_bs.head.__str__())
        if match is not None:
            doi_data = scraper.get(unquote(match.group(1)), timeout=10)
            doi_bs = BeautifulSoup(doi_data.text)
        else:
            res = doi_bs.body.find_all(id = re.compile("url|redirect", flags=re.IGNORECASE))  
            for tag in res:
                red_url = filter(lambda v: v is not None, [urlreg.search(unquote(val)) 
                    for key, val in tag.attrs.items()] )
                red_url = list(red_url)
                if len(red_url)>0:
                    match = red_url[0]
                    doi_data = scraper.get(unquote(match.group(1)), timeout=10)
                    doi_bs = BeautifulSoup(doi_data.text)
                    continue
    
    doi_bs = doi_bs.body
    
#     res2 = doi_bs.find_all(re.compile("section|p|div"), class_=re.compile("abstract", flags=re.IGNORECASE))
#     if len(res2)>0:
#         res2 = res2[0]
#         return res2.get_text().strip()
    
    res3 = doi_bs.find_all(re.compile(r"h[1-5]|text|pharos-heading"), string=re.compile(r"Summary|Abstract", flags=re.IGNORECASE))
    if len(res3)>0:
        res3=res3[0]
        sibling = res3.next_element
        while sibling.name not in ["section", "p", "div"] :
            sibling = sibling.next_element
        return sibling.get_text().strip()
    
    #Method 1
    res1 = doi_bs.find_all(re.compile("section|p|div"), class_="abstract")
    if len(res1)>0:
        res1 = res1[0]
        return res1.get_text().strip()
    
    #Search readable text -- fallback
    readable_text = doi_bs.get_text()
    pattern = re.compile(r"\n\s*Abstract\s*(.*)\n|\n\s*Summary\s*(.*)\n", flags=re.IGNORECASE)
    result = pattern.search(readable_text)
    
    
    return result.group(1).strip() if result is not None else None

# %%
doi = "10.1016/j.biocon.2017.04.010"
unidecode.unidecode(get_abstract_from_doi(doi))
# Out:
# Abstract
# ...

# %%
# !pip install js2py
# Out:
# ...
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=25998 sha256=fb4bf4ec49697560e69e99ec6ca0570989c528a914de116d750e9c1813c2f66c
#   Stored in directory: c:\users\markus\appdata\local\pip\cache\wheels\2a\80\ac\dcd2bdbd03dd2b7b7e2bf3e5afbda6a1ab7935bbce314969da
# Successfully built pyjsparser
# ...

# %%
import js2py
scraper = cloudscraper.create_scraper(browser="chrome", interpreter='js2py')
doi_data = scraper.get(f"https://www.doi.org/{doi}", allow_redirects=True)
doi_bs = BeautifulSoup(doi_data.text)

# %%
import re
from urllib.parse import unquote
pattern = re.compile(r"\?Redirect=(.*);") 
match = pattern.search(doi_bs.head.__str__())
unquote(match.group(1))
# Out:
# 'https://www.sciencedirect.com/science/article/pii/S000632071730616X?via%3Dihub&amp'

# %%
urlreg = re.compile(r"http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+")
res = doi_bs.body.find_all(id = re.compile("url|redirect", flags=re.IGNORECASE))
                    
for tag in res:
    print(tag.attrs)
    red_url = filter(lambda v: v is not None, [urlreg.search(unquote(val)) 
        for key, val in tag.attrs.items()] )
    for urlm in red_url:
        print(urlm.group(0))
# Out:
# {'type': 'hidden', 'name': 'redirectURL', 'value': 'https%3A%2F%2Fwww.sciencedirect.com%2Fscience%2Farticle%2Fpii%2FS000632071730616X%3Fvia%253Dihub', 'id': 'redirectURL'}
# https://www.sciencedirect.com/science/article/pii/S000632071730616X?via%3Dihub

# %%
res3 = doi_bs.find_all(re.compile(r"h[1-5]|text"), string=re.compile(r"Summary|Abstract"))

# %%
res3[0].next_element.next_element.next_element
# Out:
# <div class="row ArticleContentRow">
# ...
