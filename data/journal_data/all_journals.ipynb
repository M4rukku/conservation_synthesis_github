# %%
import pandas as pd

# %%
data = pd.read_json("positive_samples_v1_160221")

# %%
journals = data.loc[:, ["issn", "journal_name", "journal_volume", "journal_issue"]]

# %% [markdown]
# Split journals into those with defined and undefined issn

# %%
journals.loc[(journals["issn"]=="")] = None

# %%
journals_w_issn = journals.loc[(pd.isna(journals["issn"])==False)]
journals_wo_issn = journals.loc[pd.isna(journals["issn"])==True]

# %%
from collections import defaultdict
issn_name = defaultdict(list)

for _, row in journals_w_issn.iterrows():
    if row["journal_name"] is not None and row["journal_name"] is not "":
        issn_name[row["issn"]].append(row["journal_name"])

# %%
for key, val in issn_name.items():
    issn_name[key] = pd.unique(val).tolist()

# %%
for key, val in issn_name.items():
    if len(val)>1:
        print(f"{key} : {val}")

# %% [markdown]
# ### Standardise Names & Remove wrong entries!

# %%
name_to_standard = {'The Journal of Applied Ecology' : 'Journal of Applied Ecology',
                   'AGRICULTURE ECOSYSTEMS and ENVIRONMENT' : 'Agriculture, Ecosystems & Environment',
                    'Agriculture, Ecosystems and Environment' : 'Agriculture, Ecosystems & Environment',
                    'RESTORATION ECOLOGY' : 'Restoration Ecology',
                    'The Journal of Wildlife Management':'Journal of Wildlife Management',
                    'Waterbirds: The International Journal of Waterbird Biology' : 'Waterbirds',
                    'Animal conservation' : 'Animal Conservation',
                    'VEGETATIO' : 'Vegetatio',
                    'ICES Journal of Marine Science: Journal du Conseil': 'ICES Journal of Marine Science',
                    'The Journal of Animal Ecology':'Journal of Animal Ecology',
                    'Journal Of Insect Conservation' : 'Journal of Insect Conservation',
                    'Acta oecologica':'Acta Oecologica',
                    'PLOS ONE':'PLoS ONE',
                    'The Journal of Ecology':'Journal of Ecology',
                    'Mammalian Biology - Zeitschrift für Säugetierkunde':'Mammalian Biology',
                    'Animal welfare':'Animal Welfare',
                    'mammalia':'Mammalia',
                    'Knowledge and Management of Aquatic Ecosystems':'Knowledge & Management of Aquatic Ecosystems',
                    'AMBIO':'Ambio',
                    'Limnologica':'Limnologica - Ecology and Management of Inland Waters',
                    'Flora':'Flora - Morphology, Distribution, Functional Ecology of Plants',
                    'Bulletin français de la pêche et de la pisciculture' : 'Knowledge and Management of Aquatic Ecosystems' # CHANGED NAME 
                   }

wrong_issn = { #WRONG CONTENT
    '0767-2861' : 'Knowledge and Management of Aquatic Ecosystems', #Fixed! Correct - Name switch
    '1864-1547' : "Main Group Metal Chemistry", #Just a wrong name
    '0022-409X' : 'Rangeland Ecology & Management', #Wrong Name
    '1051-0761' : 'The Bulletin of the Ecological Society of America', #Wrong Name
}
real_issn = {
    'Rangeland Ecology & Management' : "1550-7424",
    "Main Group Metal Chemistry" : '2191-0219'
}

#WEIRD: "Journal of Cultural Economy"

# %%
# Trade for standard name
for key, val in issn_name.items():
    if len(val)>1:
        replace = []
        for el in val:
            replace.append(name_to_standard.get(el, el))
        issn_name[key] = pd.unique(replace).tolist()

# %%
# Delete wrong issn entries
for issn, val in wrong_issn.items():
        replace = list(set(issn_name[issn]) - set([val]))
        issn_name[issn] = pd.unique(replace).tolist()

# %%
# ISSN : [NAME] --> ISSN : NAME
issn_name = {issn:name[0] for issn, name in issn_name.items()}

# %% [markdown]
# ### Process entries without issn

# %%
journals_wo_issn = journals_wo_issn.loc[pd.isna(journals_wo_issn["journal_name"])==False]

# %%
unknown_names = []
for key, row in journals_wo_issn.iterrows():
    if row["journal_name"] in issn_name.values():
        continue
    else:
        unknown_names.append(row["journal_name"])

# %%
unknown_names
# Out:
# ['Zoological Science', 'Journal of Cultural Economy']

# %%
unknown_issn_name = {
   "2212-3830" : 'Zoological Science',
   #"0289-0003" : 'Zoological Science', #PRINT
   "1753-0369" : "Journal of Cultural Economy",
#     "1753-0350": "Journal of Cultural Economy"#PRINT
}

# %%
issn_name.update(unknown_issn_name)

# %%
issn_name
# Out:
# {'0021-8901': 'Journal of Applied Ecology',
#  '0929-1393': 'Applied Soil Ecology',
#  '1528-7092': 'Southeastern Naturalist',
#  '0006-3207': 'Biological Conservation',
#  '0006-3657': 'Bird Study',
#  '0305-1838': 'Mammal Review',
#  '0030-6053': 'Oryx',
#  '0167-8809': 'Agriculture, Ecosystems & Environment',
#  '0273-8570': 'Journal of Field Ornithology',
#  '1061-2971': 'Restoration Ecology',
#  '0003-6862': 'Applied Entomology and Zoology',
#  '0888-8892': 'Conservation Biology',
#  '0261-2194': 'Crop Protection',
#  '0022-541X': 'Journal of Wildlife Management',
#  '1524-4695': 'Waterbirds',
#  '1051-0761': 'Ecological Applications',
#  '0722-4060': 'Polar Biology',
#  '1367-9430': 'Animal Conservation',
#  '0018-506X': 'Hormones and Behavior',
#  '0043-5643': 'The Wilson Bulletin',
#  '0378-1127': 'Forest Ecology and Management',
#  '0010-5422': 'The Condor',
#  '0960-3115': 'Biodiversity and Conservation',
#  '0030-5693': 'Ornis Scandinavica',
#  '0042-3106': 'Vegetatio',
#  '0959-2709': 'Bird Conservation International',
#  '1385-0237': 'Plant Ecology',
#  '0738-6028': 'Colonial Waterbirds',
#  '0004-8038': 'The Auk',
#  '1612-4642': 'European Journal of Wildlife Research',
#  '1938-4254': 'The Auk',
#  '0019-1019': 'Ibis',
#  '0032-8332': 'Primates',
#  '0021-8790': 'Journal of Animal Ecology',
#  '0307-6946': 'Ecological Entomology',
#  '0908-8857': 'Journal of Avian Biology',
#  '0030-1299': 'Oikos',
#  '0158-4197': 'Emu - Austral Ornithology',
#  '1366-638X': 'Journal of Insect Conservation',
#  '0022-8567': 'Journal of the Kansas Entomological Society',
#  '1938-291X': 'Journal of Economic Entomology',
#  '0008-347X': 'The Canadian Entomologist',
#  '0021-8839': 'Journal of Apicultural Research',
#  '1559-4491': 'The Wilson Journal of Ornithology',
#  '0022-2011': 'Journal of Invertebrate Pathology',
#  '0305-7364': 'Annals of Botany',
#  '0002-1962': 'Agronomy Journal',
#  '0006-3185': 'The Biological Bulletin',
#  '1438-3896': 'Population Ecology',
#  '0165-0521': 'Studies on Neotropical Fauna and Environment',
#  '0044-8435': 'Apidologie',
#  '0005-772X': 'Bee World',
#  '1938-2936': 'Environmental Entomology',
#  '0022-409X': 'Journal of Range Management',
#  '0046-225X': 'Environmental Entomology',
#  '1932-7048': 'Cities and the Environment',
#  '1092-6194': 'Northeastern Naturalist',
#  '0012-9658': 'Ecology',
#  '1744-6961': 'Grassland Science',
#  '0033-0779': 'The Progressive Fish-Culturist',
#  '1522-2055': 'North American Journal of Aquaculture',
#  '1054-3139': 'ICES Journal of Marine Science',
#  '0144-8609': 'Aquacultural Engineering',
#  '0967-6120': 'Aquaculture International',
#  '0969-997X': 'Fisheries Management and Ecology',
#  '0909-6396': 'Wildlife Biology',
#  '0301-4797': 'Journal of Environmental Management',
#  '0906-7590': 'Ecography',
#  '0022-4588': 'Journal of Soil Science',
#  '0021-8375': 'Journal of Ornithology',
#  '0031-4056': 'Pedobiologia',
#  '0167-1987': 'Soil and Tillage Research',
#  '1164-5563': 'European Journal of Soil Biology',
#  '1402-2001': 'Applied Vegetation Science',
#  '0169-2046': 'Landscape and Urban Planning',
#  '0931-2048': 'Journal of Applied Entomology',
#  '0029-8549': 'Oecologia',
#  '0022-2933': 'Journal of Natural History',
#  '1526-498X': 'Pest Management Science',
#  '0144-8765': 'Biological Agriculture & Horticulture',
#  '0021-8596': 'The Journal of Agricultural Science',
#  '0142-5242': 'Grass and Forage Science',
#  '1617-1381': 'Journal for Nature Conservation',
#  '0043-1737': 'Weed Research',
#  '0906-4710': 'Acta Agriculturae Scandinavica, Section B - Plant Soil Science',
#  '1461-9555': 'Agricultural and Forest Entomology',
#  '0791-7945': 'Biology & Environment: Proceedings of the Royal Irish Academy',
#  '0003-4746': 'Annals of Applied Biology',
#  '0038-0717': 'Soil Biology and Biochemistry',
#  '0952-8369': 'Journal of Zoology',
#  '0892-7936': 'Anthrozoös',
#  '0308-597X': 'Marine Policy',
#  '0364-152X': 'Environmental Management',
#  '1146-609X': 'Acta Oecologica',
#  '1439-1791': 'Basic and Applied Ecology',
#  '1540-9295': 'Frontiers in Ecology and the Environment',
#  '0892-1016': 'Journal of Raptor Research',
#  '2193-7192': 'Journal of Ornithology',
#  '1522-4740': 'Ecological Restoration',
#  '0140-1963': 'Journal of Arid Environments',
#  '0091-7648': 'Wildlife Society Bulletin',
#  '0253-1453': 'Botanica Helvetica',
#  '1387-3547': 'Biological Invasions',
#  '0269-283X': 'Medical and Veterinary Entomology',
#  '1357-7298': 'Animal Science',
#  '0008-4301': 'Canadian Journal of Zoology',
#  '1195-6860': 'Écoscience',
#  '0013-8703': 'Entomologia Experimentalis et Applicata',
#  '0028-2960': 'Netherlands Journal of Zoology',
#  '0733-3188': 'Zoo Biology',
#  '0376-8929': 'Environmental Conservation',
#  '1100-9233': 'Journal of Vegetation Science',
#  '1536-2442': 'Journal of Insect Science',
#  '0301-5521': 'New Zealand Journal of Experimental Agriculture',
#  '0003-1062': 'Journal of the American Society for Horticultural Science',
#  '0967-0874': 'International Journal of Pest Management',
#  '1049-9644': 'Biological Control',
#  '1978-3019': 'Hayati Journal of Biosciences',
#  '0018-5345': 'HortScience',
#  '0098-0331': 'Journal of Chemical Ecology',
#  '0003-0589': 'American Potato Journal',
#  '1742-7584': 'International Journal of Tropical Insect Science',
#  '1444-6162': 'Weed Biology and Management',
#  '0030-7270': 'Outlook on Agriculture',
#  '0931-2250': 'Journal of Agronomy and Crop Science',
#  '0567-7572': 'Acta Horticulturae',
#  '1436-5693': 'Anzeiger fur Sch<html_ent glyph="@auml;" ascii="a"/>dlingskunde',
#  '1044-0046': 'Journal of Sustainable Agriculture',
#  '0007-4853': 'Bulletin of Entomological Research',
#  '1535-1025': 'Plant Health Progress',
#  '1475-2743': 'Soil Use and Management',
#  '0266-0032': 'Soil Use and Management',
#  '0016-7061': 'Geoderma',
#  '1838-675X': 'Soil Research',
#  '1385-1314': 'Nutrient Cycling in Agroecosystems',
#  '0095-3628': 'Microbial Ecology',
#  '1161-0301': 'European Journal of Agronomy',
#  '1862-4065': 'Sustainability Science',
#  '0044-8486': 'Aquaculture',
#  '0140-7775': 'Journal of Fish Diseases',
#  '0264-410X': 'Vaccine',
#  '0034-5288': 'Research in Veterinary Science',
#  '1355-557X': 'Aquaculture Research',
#  '0892-7014': 'Biofouling',
#  '1611-2490': 'Paddy and Water Environment',
#  '0022-1511': 'Journal of Herpetology',
#  '0441-6651': 'The Journal of the Herpetological Association of Africa',
#  '0277-5212': 'Wetlands',
#  '0173-5373': 'Amphibia-Reptilia',
#  '0074-9664': 'International Zoo Yearbook',
#  '1570-7539': 'Applied Herpetology',
#  '0925-8574': 'Ecological Engineering',
#  '0011-2240': 'Cryobiology',
#  '0301-4223': 'New Zealand Journal of Zoology',
#  '0269-7491': 'Environmental Pollution',
#  '0018-0831': 'Herpetologica',
#  '0177-5103': 'Diseases of Aquatic Organisms',
#  '1687-9708': 'International Journal of Ecology',
#  '1470-1626': 'Reproduction',
#  '1076-3139': 'Bulletin of the Association of Reptilian and Amphibian Veterinarians',
#  '0045-8511': 'Copeia',
#  '1434-2944': 'International Review of Hydrobiology',
#  '0067-2238': 'Australian Zoologist',
#  '1932-6203': 'PLoS ONE',
#  '1051-1733': 'Northwestern Naturalist',
#  '1863-5407': 'Endangered Species Research',
#  '0003-0031': 'The American Midland Naturalist',
#  '1052-7613': 'Aquatic Conservation: Marine and Freshwater Ecosystems',
#  '0093-691X': 'Theriogenology',
#  '0038-4909': 'The Southwestern Naturalist',
#  '1527-0904': 'Western North American Naturalist',
#  '1056-8719': 'Journal of Pharmacological and Toxicological Methods',
#  '0090-3558': 'Journal of Wildlife Diseases',
#  '1035-3712': 'Wildlife Research',
#  '0015-7546': 'The Forestry Chronicle',
#  '1042-7260': 'Journal of Zoo and Wildlife Medicine',
#  '1742-1705': 'Renewable Agriculture and Food Systems',
#  '0257-1862': 'South African Journal of Plant and Soil',
#  '1002-0071': 'Progress in Natural Science',
#  '0095-3679': 'Peanut Science',
#  '0816-1089': 'Australian Journal of Experimental Agriculture',
#  '0749-8004': 'Journal of Entomological Science',
#  '0191-2917': 'Plant Disease',
#  '0013-8959': 'Entomophaga',
#  '0008-0845': 'California Agriculture',
#  '2224-7904': 'South African Journal of Enology & Viticulture',
#  '0178-2762': 'Biology and Fertility of Soils',
#  '1439-0108': 'Journal of Soils and Sediments',
#  '0008-4271': 'Canadian Journal of Soil Science',
#  '0022-2372': 'Journal of Mammalogy',
#  '1392-1657': 'Acta Zoologica Lituanica',
#  '1944-687X': 'Journal of Fish and Wildlife Management',
#  '1508-1109': 'Acta Chiropterologica',
#  '0025-326X': 'Marine Pollution Bulletin',
#  '0046-5070': 'Freshwater Biology',
#  '1179-352X': 'New Zealand Plant Protection',
#  '0090-4341': 'Archives of Environmental Contamination and Toxicology',
#  '0031-935X': 'Physiological Zoology',
#  '1464-3766': 'Journal of Molluscan Studies',
#  '0018-8158': 'Hydrobiologia',
#  '1038-2097': 'Pacific Conservation Biology',
#  '1054-9811': 'Journal of Sustainable Forestry',
#  '1028-8880': 'Pakistan Journal of Biological Sciences',
#  '0015-752X': 'Forestry',
#  '0045-5067': 'Canadian Journal of Forest Research',
#  '1442-9985': 'Austral Ecology',
#  '0004-9158': 'Australian Forestry',
#  '0006-3606': 'Biotropica',
#  '1212-4834': 'Journal of Forest Science',
#  '1095-5674': 'The Journal of the Torrey Botanical Society',
#  '0029-344X': 'Northwest Science',
#  '0169-4286': 'New Forests',
#  '0028-825X': 'New Zealand Journal of Botany',
#  '0961-9534': 'Biomass and Bioenergy',
#  '0024-2829': 'The Lichenologist',
#  '1755-0874': 'Plant Ecology & Diversity',
#  '0742-6348': 'Northern Journal of Applied Forestry',
#  '0885-6095': 'Western Journal of Applied Forestry',
#  '1550-7424': 'Rangeland Ecology & Management',
#  '1007-662X': 'Journal of Forestry Research',
#  '1433-8319': 'Perspectives in Plant Ecology, Evolution and Systematics',
#  '0885-8608': 'Natural Areas Journal',
#  '1933-9747': 'Fire Ecology',
#  '1088-8705': 'Journal of Applied Animal Welfare Science',
#  '1879-4238': 'Organic Agriculture',
#  '0361-5995': 'Soil Science Society of America Journal',
#  '0043-1745': 'Weed Science',
#  '0032-079X': 'Plant and Soil',
#  '0940-6360': 'Mycorrhiza',
#  '0022-4561': 'Journal of Soil and Water Conservation',
#  '0047-2425': 'Journal of Environmental Quality',
#  '0275-5947': 'North American Journal of Fisheries Management',
#  '0022-0477': 'Journal of Ecology',
#  '1354-1013': 'Global Change Biology',
#  '0275-2565': 'American Journal of Primatology',
#  '0898-6207': 'Primate Conservation',
#  '0164-0291': 'International Journal of Primatology',
#  '0015-5713': 'Folia Primatologica',
#  '1421-9980': 'Folia Primatologica',
#  '1040-2381': 'Lake and Reservoir Management',
#  '1939-7291': 'Invasive Plant Science and Management',
#  '1442-7001': 'Ecological Management & Restoration',
#  '0254-6299': 'South African Journal of Botany',
#  '0923-4861': 'Wetlands Ecology and Management',
#  '2095-0195': 'Frontiers of Earth Science',
#  '0964-0568': 'Journal of Environmental Planning and Management',
#  '1439-8621': 'Limnology',
#  '1432-9840': 'Ecosystems',
#  '0168-1591': 'Applied Animal Behaviour Science',
#  '0008-3550': 'The Canadian Field-Naturalist',
#  '0960-9822': 'Current Biology',
#  '1616-5047': 'Mammalian Biology',
#  '0023-6772': 'Laboratory Animals',
#  '0962-7286': 'Animal Welfare',
#  '0141-1136': 'Marine Environmental Research',
#  '1095-9289': 'ICES Journal of Marine Science',
#  '0272-7714': 'Estuarine, Coastal and Shelf Science',
#  '0025-3154': 'Journal of the Marine Biological Association of the United Kingdom',
#  '0171-8630': 'Marine Ecology Progress Series',
#  '1400-0350': 'Journal of Coastal Conservation',
#  '1755-263X': 'Conservation Letters',
#  '1463-4988': 'Aquatic Ecosystem Health & Management',
#  '0165-7836': 'Fisheries Research',
#  '2047-2382': 'Environmental Evidence',
#  '1385-1101': 'Journal of Sea Research',
#  '1566-0621': 'Conservation Genetics',
#  '0990-7440': 'Aquatic Living Resources',
#  '0722-4028': 'Coral Reefs',
#  '0011-216X': 'Crustaceana',
#  '0310-0049': 'Australian Mammalogy',
#  '2199-2401': 'Mammal Research',
#  '1938-5463': 'Wildlife Society Bulletin',
#  '2296-701X': 'Frontiers in Ecology and Evolution',
#  '1125-0003': 'Italian Journal of Zoology',
#  '1864-1547': 'Mammalia',
#  '0001-7051': 'Acta Theriologica',
#  '1545-1542': 'Journal of Mammalogy',
#  '0141-6707': 'African Journal of Ecology',
#  '0379-4369': 'South African Journal of Wildlife Research',
#  '0025-1461': 'Mammalia',
#  '1343-4152': 'Mammal Study',
#  '0824-0469': 'Marine Mammal Science',
#  '0394-9370': 'Ethology Ecology & Evolution',
#  '1940-0829': 'Tropical Conservation Science',
#  '1543-4060': 'Ecological Restoration',
#  '0266-4674': 'Journal of Tropical Ecology',
#  '2007-3364': 'Therya',
#  '0163-1047': 'Behavioral and Neural Biology',
#  '1936-0614': 'Bears: Their Biology and Management',
#  '1537-6176': 'Ursus',
#  '0003-3472': 'Animal Behaviour',
#  '1529-9651': 'Journal of Herpetological Medicine and Surgery',
#  '1961-9502': 'Knowledge & Management of Aquatic Ecosystems',
#  '2351-9894': 'Global Ecology and Conservation',
#  '1612-9202': 'EcoHealth',
#  '2156-4574': 'African Journal of Herpetology',
#  '0093-4526': 'The Journal of Zoo Animal Medicine',
#  '0022-0981': 'Journal of Experimental Marine Biology and Ecology',
#  '1323-1650': 'Marine and Freshwater Research',
#  '1071-8443': 'Chelonian Conservation and Biology',
#  '2076-2615': 'Animals',
#  '0028-8330': 'New Zealand Journal of Marine and Freshwater Research',
#  '0706-652X': 'Canadian Journal of Fisheries and Aquatic Sciences',
#  '0921-4488': 'Small Ruminant Research',
#  '2049-257X': 'Journal of Applied Animal Nutrition',
#  '1664-1078': 'Frontiers in Psychology',
#  '0376-6357': 'Behavioural Processes',
#  '2405-6545': 'Animal Nutrition',
#  '0093-7355': 'Lab Animal',
#  '1488-8386': 'Biodiversity',
#  '1345-5834': 'Current Herpetology',
#  '1435-9448': 'Animal Cognition',
#  '0394-6975': 'Tropical Zoology',
#  '2095-0357': 'Asian Herpetological Research',
#  '2296-7745': 'Frontiers in Marine Science',
#  '1939-2087': 'Journal of Comparative Psychology',
#  '0173-9565': 'Marine Ecology',
#  '0167-5427': 'Aquatic Mammals',
#  '0735-7036': 'Journal of Comparative Psychology',
#  '0570-7358': 'Ardeola',
#  '1939-1846': 'Journal of Abnormal Psychology',
#  '1031-3613': 'Reproduction, Fertility and Development',
#  '0047-2565': 'Journal of Medical Primatology',
#  '0974-7893': 'Journal of Threatened Taxa',
#  '0378-4320': 'Animal Reproduction Science',
#  '1765-2952': 'Aquatic Living Resources',
#  '0749-0208': 'Journal of Coastal Research',
#  '1467-2960': 'Fish and Fisheries',
#  '0363-2415': 'Fisheries',
#  '1461-023X': 'Ecology Letters',
#  '0169-5347': 'Trends in Ecology & Evolution',
#  '0066-4170': 'Annual Review of Entomology',
#  '0380-1330': 'Journal of Great Lakes Research',
#  '2091-0363': 'Journal of Wetlands Ecology',
#  '1814-232X': 'African Journal of Marine Science',
#  '0954-1020': 'Antarctic Science',
#  '2352-4855': 'Regional Studies in Marine Science',
#  '1054-6006': 'Fisheries Oceanography',
#  '1341-6979': 'Journal of Forest Research',
#  '0044-7447': 'Ambio',
#  '0855-4307': 'West African Journal of Applied Ecology',
#  '0257-7615': 'South African Journal of Marine Science',
#  '1559-2723': 'Estuaries and Coasts',
#  '1386-2588': 'Aquatic Ecology',
#  '1380-8427': 'Netherlands Journal of Aquatic Ecology',
#  '2578-4994': 'Journal of Ecology & Natural Resources',
#  '0886-9375': 'Regulated Rivers: Research & Management',
#  '1535-1459': 'River Research and Applications',
#  '0767-2861': 'Bulletin Français de la Pêche et de la Pisciculture',
#  '0075-9511': 'Limnologica - Ecology and Management of Inland Waters',
#  '0022-0949': 'Journal of Experimental Biology',
#  '0165-1404': 'Hydrobiological Bulletin',
#  '0077-7579': 'Netherlands Journal of Sea Research',
#  '0960-3166': 'Reviews in Fish Biology and Fisheries',
#  '0367-2530': 'Flora - Morphology, Distribution, Functional Ecology of Plants',
#  '1752-458X': 'Insect Conservation and Diversity',
#  '0304-3770': 'Aquatic Botany',
#  '1543-592X': 'Annual Review of Ecology, Evolution, and Systematics',
#  '1058-5893': 'International Journal of Plant Sciences',
#  '0036-8075': 'Science',
#  '1864-7782': 'Aquatic Biology',
#  '1519-566X': 'Neotropical Entomology',
#  '2161-9549': 'Freshwater Science',
#  '1314-3301': 'Nature Conservation',
#  '1744-9561': 'Biology Letters',
#  '0730-8000': 'Journal of Shellfish Research',
#  '0733-1347': 'Herpetological Monographs',
#  '2212-3830': 'Zoological Science',
#  '1753-0369': 'Journal of Cultural Economy'}

# %% [markdown]
# CHECK FOR UNIQUENESS OF ISSN

# %%
len(set(issn_name.keys()))
# Out:
# 369

# %%
len(issn_name)
# Out:
# 369

# %%
import json
from pathlib import Path

store_journal_issn_map = Path(".") / "issn_journal_map.json"
with store_journal_issn_map.open("w") as f:
    json.dump(issn_name, f)

# %%
store_journal_issn_map = Path(".") / "journal_name_to_standard.json"
with store_journal_issn_map.open("w") as f:
    json.dump(name_to_standard, f)

# %% [markdown]
# Standardise use of ISSN / JOURNAL NAMES

# %%
otherIndex = data.set_index(keys="issn", drop=False)

# %% [markdown]
# Fix wrong_issns!

# %%
otherIndex.loc['0767-2861', "issn"]='1961-9502' # Update to '1961-9502' Knowledge and Management of Aquatic Ecosystems

# %% [markdown]
# UPDATE ALL NAMES WITH ISSNs

# %%
otherIndex.reset_index(inplace=True, drop=True)

# %%
for ind, row in otherIndex.iterrows():
    if pd.isna(row['issn']) == False and row['issn']!="":
        otherIndex.loc[ind, "journal_name"] = issn_name.get(row['issn'])

# %%
name_issn = {name : issn for issn, name in issn_name.items()}

# %%
for ind, row in otherIndex.loc[pd.isna(otherIndex["issn"])==True].iterrows():
    name = otherIndex.loc[ind, "journal_name"]
    if name in name_issn:
        otherIndex.loc[ind, "issn"] = name_issn[name]

# %%
otherIndex.loc[pd.isna(otherIndex["issn"])]
# Out:
#                                                    title  \
# 118    Impact of habitat management on grey partridge...
# 950    Dispersal of carabid species along a linear se...
# 2024   Cover Crops and Related Methods for Enhancing ...
# 2311   Relations of native and exotic species 5 years...
# 2716   Provisioning and tourism in free-ranging Japan...
# 3301   The swift fox reintroduction program in Canada...
# 3306   Use of Electric Fencing and Associated Measure...
# 4576   Hepatic iron accumulation over time in Europea...
# 5756   Ecological husbandry and reproduction of the M...
# 6083   Implementing new portable touchscreen-setups t...
# 10972  Annual variability in survival of sea-ranched ...
# 12747  Residual herbicide treatments reduce <i>Androp...
# 13490  Reduction of Microcystis blooms in a hypertrop...
# 14407  Guilds and diversity of ants in three land use...
# 15187  Food-web manipulation in a small, eutrophic La...
# 17769  Nesting and conservation of the Olive Ridley s...
# 17842  Repatriated Malagasy tortoises contribute to t...
#
#                                                  authors  \
# 118    [Pierre Mayot, Eve Corda, François Reitz, Elis...
# 950                                         [H. Gruttke]
# 2024       [Hugh A. Smith, J. M. Holland, P. G. Tillman]
# 2311             [Timothy B. Harrington, David H. Peter]
# 2716                                   [Hiroyuki Kurita]
# 3301   [Ludwig N.Carbyn, Harry J.Armbruster, CharlesM...
# 3306   [Fernando R. Tortato, Sandra M. C. Cavalcanti,...
# 4576   [Michael T. Maslanka, Susan D. Crissey, Susan ...
# 5756                                    [Daniel Pearson]
# 6083                                   [Vanessa Schmitt]
# 10972        [Sakari Kuikka, Matti Salminen, Esa Erkamo]
# 12747  [Natalie A. Rossiter-Rachor, Linda Luck, Sean ...
# 13490  [Michael Opitz, Andreas Meybohm, Jürgen Benndo...
# 14407          [Anderson Arenas-Clavijo, Inge Armbrecht]
# 15187    [Krystyna Prejs, Paweł Koperski, Andrzej Prejs]
# 17769                       [David Melero, Robert James]
# 17842                              [Léon Razafindrakoto]
#
#                                                    doi publication_date  \
# 118                   10.1111/j.0021-8901.2004.00939.x             None
# 950                       10.1007/978-94-017-0968-2_45             None
# 2024                        10.1002/9781118231838.ch19             None
# 2311                                10.2737/pnw-rp-589             None
# 2716                      10.1017/cbo9781139087407.005             None
# 3301                      10.1017/cbo9780511623325.014       1994-10-27
# 3306                      10.1007/978-1-4614-0902-1_16             None
# 4576   10.1638/1042-7260(2000)031[0491:hiaoti]2.0.co;2             None
# 5756                             10.3854/crm.6.a24p146       2013-11-27
# 6083                                    10.1101/316042             None
# 10972               10.1111/j.1365-2400.1995.tb00110.x             None
# 12747                                10.1111/emr.12376             None
# 13490                      10.1007/978-94-017-2986-4_3             None
# 14407                         10.15517/rbt.v66i1.30269             None
# 15187                     10.1007/978-94-011-5648-6_39             None
# 17769                         10.15517/rbt.v63i1.23099             None
# 17842                            10.3854/crm.6.a22p132       2013-11-27
#
#                                                 abstract repo_identifier  \
# 118    1 The grey partridge is a species of conservat...        openaire
# 950                                                 None        openaire
# 2024   This chapter contains sections titled:\n\n    ...        openaire
# 2311                                                None        openaire
# 2716   IntroductionPrimate-focused tourism in Japan b...        openaire
# 3301   IntroductionThe swift fox (Vulpes velox), the ...        crossref
# 3306   The Pantanal of Brazil is an important area fo...        openaire
# 4576   European starlings (Sturnus vulgaris) were use...        openaire
# 5756                                                None        openaire
# 6083   <jats:title>Abstracts</jats:title><jats:p>To u...        openaire
# 10972  Carlin tagging data for 1980–1991 were used to...        openaire
# 12747  Weed invasion is a major threat to Australian ...        openaire
# 13490  In Bautzen reservoir, a shallow, hypertrophic ...        openaire
# 14407  Resumen En los últimos 50 años, la producción ...        openaire
# 15187  The effect of fish removal on the invertebrate...        openaire
# 17769  Resumen Desde 2006 a 2012, la anidación de la ...        openaire
# 17842                                               None        openaire
#
#       language                                          publisher  \
# 118         EN                                              Wiley
# 950         EN                               Springer Netherlands
# 2024        EN                             John Wiley & Sons, Ltd
# 2311        EN  U.S. Department of Agriculture, Forest Service...
# 2716        EN                         Cambridge University Press
# 3301        EN                         Cambridge University Press
# 3306        EN                                  Springer New York
# 4576        EN                                               None
# 5756        EN                      Chelonian Research Foundation
# 6083        EN                      Cold Spring Harbor Laboratory
# 10972       EN                                              Wiley
# 12747       EN                                              Wiley
# 13490       EN                               Springer Netherlands
# 14407       EN                          Universidad de Costa Rica
# 15187       EN                               Springer Netherlands
# 17769       EN                          Universidad de Costa Rica
# 17842       EN                      Chelonian Research Foundation
#
#       journal_name journal_volume journal_issue  issn  \
# 118           None           None          None  None
# 950           None           None          None  None
# 2024          None           None          None  None
# 2311          None           None          None  None
# 2716          None           None          None  None
# 3301          None           None          None  None
# 3306          None           None          None  None
# 4576          None           None          None  None
# 5756          None           None          None  None
# 6083          None           None          None  None
# 10972         None           None          None  None
# 12747         None           None          None  None
# 13490         None           None          None  None
# 14407         None           None          None  None
# 15187         None           None          None  None
# 17769         None           None          None  None
# 17842         None           None          None  None
#
#                                                   url  index abstract_origin  \
# 118                                              None    144            repo
# 950                                              None   1252    invalid_repo
# 2024                                             None   2752         scraped
# 2311                                             None   3097            repo
# 2716                                             None   3548         scraped
# 3301   http://dx.doi.org/10.1017/cbo9780511623325.014   4246         scraped
# 3306                                             None   4253            repo
# 4576                                             None   5866            repo
# 5756                                             None   7264            repo
# 6083                                             None   7652            repo
# 10972                                            None  12923            repo
# 12747                                            None  14793         scraped
# 13490                                            None  15609            repo
# 14407                                            None  16654            repo
# 15187                                            None  17484            repo
# 17769                                            None  20328            repo
# 17842                                            None  20452            repo
#
#                                     topic_classification
# 118                                      Birds; Farmland
# 950                                             Farmland
# 2024                                            Farmland
# 2311                                            Farmland
# 2716                                             Mammals
# 3301                                             Mammals
# 3306                                             Mammals
# 4576                                     Animals ex-situ
# 5756                                     Animals ex-situ
# 6083                                     Animals ex-situ
# 10972                                               Fish
# 12747      Grassland/Savanna; Invasive or problem plants
# 13490  Invasive or problem bacteria/other living agen...
# 14407                                      Invertebrates
# 15187                                      Invertebrates
# 17769                                           Reptiles
# 17842                                           Reptiles

# %%
new_isbn_fields = {"0034-7744": "Revista de Biología Tropical",
                  "1442-7001" : "Ecological Management & Restoration."}

fill_empty_fields = { #ind, issn, journal_name
    118:"0021-8901",
    #950:""BOOK
    #2024:  BOOK
    #2311 Grey
    #2716 BOOK
    #3301 BOOK
    #3306 BOOK
    4576: "1042-7260",
    10972: "0969-997X",
    17769:"0034-7744",
    14407:"0034-7744",
    12747:"1442-7001",
    
}

issn_name.update(new_isbn_fields)

# %%
for ind, issn in fill_empty_fields.items():
    otherIndex.loc[ind, "issn"] = issn
    otherIndex.loc[ind, "journal_name"] = issn_name[issn]

# %% [markdown]
# Clear away any tags in titles / abstracts!

# %%
import re
pattern = re.compile(r"<jats:\w*>|</jats:\w*>")

# %%
test = otherIndex.loc[6083, "abstract"]

# %%
for ind, row in otherIndex.iterrows():
    if row["abstract"] is not None:
        otherIndex.loc[ind, "abstract"] = pattern.sub(" ", row["abstract"])

# %%
pattern = re.compile(r"<\w*>|</\w*>")

# %%
for ind, row in otherIndex.iterrows():
    if row["abstract"] is not None:
        otherIndex.loc[ind, "abstract"] = pattern.sub(" ", row["abstract"])

# %%
for ind, row in otherIndex.iterrows():
    if row["title"] is not None:
        otherIndex.loc[ind, "title"] = pattern.sub(" ", row["title"])

# %%
otherIndex
# Out:
#                                                    title  \
# 0       The Management of Grass Pastures for Brent Geese
# 1            Control of Molinia caerulea on upland moors
# 2      Long-distance relocation of nestboxes reduces ...
# 3      Reducing the density of breeding gulls influen...
# 4      Elements that promote highway crossing structu...
# ...                                                  ...
# 18188  Historical peat loss explains limited short-te...
# 18189  Wood chip soil amendments in restored wetlands...
# 18190  Is the cutting of oil contaminated marshes an ...
# 18191  Restoration of inland brackish vegetation by l...
# 18192  Seed arrival and persistence at the tidal mudf...
#
#                                                  authors  \
# 0             [J. A.Vickery, W. J.Sutherland, S. J.Lane]
# 1      [R. H.Marrs, J. D. P.Phillips, P. A.Todd, J.Gh...
# 2      [AlbertoSorace, FabrizioPetrassi, CarloConsiglio]
# 3      [S. K.Finney, M. P.Harris, L. F.Keller, D. A.E...
# 4               [WayneMcDonald, Colleen CassadySt Clair]
# ...                                                  ...
# 18188  [Jennifer Williamson, David Norris, Chris D. E...
# 18189    [Evan C.Wolf, EliškaRejmánková, David J.Cooper]
# 18190  [André L.T.O.Wolinski, Paulo C.Lana, LeonardoS...
# 18191  [MinekeWolters, Saskiade Vries, Wim A.Ozinga, ...
# 18192      [ZZhu, TJBouma, TYsebaert, LZhang, PMJHerman]
#
#                                     doi publication_date  \
# 0                       10.2307/2404543           1994-5
# 1      10.1111/j.0021-8901.2004.00901.x           2004-4
# 2             10.1080/00063650409461343           2004-7
# 3      10.1046/j.1365-2664.2003.00810.x           2003-6
# 4      10.1111/j.1365-2664.2004.00877.x        2004-2-12
# ...                                 ...              ...
# 18188     10.1016/j.jenvman.2016.12.018           2017-3
# 18189                 10.1111/rec.12942         2019-4-2
# 18190   10.1016/j.marpolbul.2011.03.024           2011-6
# 18191                10.1111/avsc.12323        2017-8-20
# 18192                 10.3354/meps10920       2014-10-22
#
#                                                 abstract repo_identifier  \
# 0      An increasing number of brent geese now feed i...        crossref
# 1      1 Molinia encroachment has been viewed as a ma...        crossref
# 2      Capsule Clutches of hole-nesting passerines su...        crossref
# 3      1 By acting as both competitors and predators,...        crossref
# 4      1 \nCorridors provide important structural con...        crossref
# ...                                                  ...             ...
# 18188  This study assessed the short-term impacts of ...        openaire
# 18189  Adding chipped wood to soil ameliorates compac...        crossref
# 18190  Cutting and removal of oil-impacted marsh plan...        crossref
# 18191  Question Does large-scale transfer of coastal ...        crossref
# 18192  Salt marshes are highly valuable ecosystems th...        crossref
#
#       language                      publisher  \
# 0           EN                          JSTOR
# 1           EN                          Wiley
# 2           EN             Informa UK Limited
# 3           EN                          Wiley
# 4           EN                          Wiley
# ...        ...                            ...
# 18188       EN                    Elsevier BV
# 18189       EN                          Wiley
# 18190       EN                    Elsevier BV
# 18191       EN                          Wiley
# 18192       EN  Inter-Research Science Center
#
#                               journal_name journal_volume journal_issue  \
# 0               Journal of Applied Ecology             31             2
# 1               Journal of Applied Ecology             41             2
# 2                               Bird Study             51             2
# 3               Journal of Applied Ecology             40             3
# 4               Journal of Applied Ecology             41             1
# ...                                    ...            ...           ...
# 18188  Journal of Environmental Management            188
# 18189                  Restoration Ecology             27             5
# 18190            Marine Pollution Bulletin             62             6
# 18191           Applied Vegetation Science             20             4
# 18192       Marine Ecology Progress Series            513
#
#             issn                                                url  index  \
# 0      0021-8901                  http://dx.doi.org/10.2307/2404543      0
# 1      0021-8901  http://dx.doi.org/10.1111/j.0021-8901.2004.009...      2
# 2      0006-3657        http://dx.doi.org/10.1080/00063650409461343      3
# 3      0021-8901  http://dx.doi.org/10.1046/j.1365-2664.2003.008...      4
# 4      0021-8901  http://dx.doi.org/10.1111/j.1365-2664.2004.008...      5
# ...          ...                                                ...    ...
# 18188  0301-4797    http://dx.doi.org/10.1016/j.jenvman.2016.12.018  20893
# 18189  1061-2971                http://dx.doi.org/10.1111/rec.12942  20894
# 18190  0025-326X  http://dx.doi.org/10.1016/j.marpolbul.2011.03.024  20895
# 18191  1402-2001               http://dx.doi.org/10.1111/avsc.12323  20896
# 18192  0171-8630                http://dx.doi.org/10.3354/meps10920  20898
#
#       abstract_origin topic_classification
# 0                repo      Farmland; Birds
# 1                repo            Shrubland
# 2             scraped                Birds
# 3                repo                Birds
# 4             scraped              Mammals
# ...               ...                  ...
# 18188            repo              Wetland
# 18189         scraped              Wetland
# 18190         scraped              Wetland
# 18191            repo              Wetland
# 18192            repo              Wetland
#
# [18193 rows x 16 columns]

# %%
otherIndex.to_json("positive_samples_v2_170221_corrected_journals_removed_tags")

# %%
otherIndex = otherIndex.loc[otherIndex["issn"]!="0034-7744"]

# %%
otherIndex.to_json("positive_samples_v2_1_170221_removed_spani")

# %% [markdown]
# Get Data about Volume + Issue of Journals

# %%
import json
from pathlib import Path

data = pd.read_json("positive_samples_v2_170221_corrected_journals_removed_tags")
with open("issn_journal_map.json") as f:
    issn_name = json.load(f)

# %%
from collections import defaultdict
issn_vol_iss = defaultdict(list)

for ind, row in data.iterrows():
    if row['issn'] is not None:
        vol = row["journal_volume"]
        iss = row["journal_issue"]
        issn_vol_iss[row['issn']].append((vol, iss))

# %%
for key, val in issn_vol_iss.items():
    issn_vol_iss[key] = pd.unique(val).tolist()

# %%
for key, val in issn_vol_iss.items():
    issn_vol_iss[key] = [v for v in val if v[0] is not None and v[0]!=""]

# %%
with open("issn_vol_iss_map.json", "w") as f:
    json.dump(issn_vol_iss, f)

# %% [markdown]
# Get amount of entries per volume
